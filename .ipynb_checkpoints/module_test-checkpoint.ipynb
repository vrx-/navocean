# %%
import sailboat as sb # local file sailboat.py
## this is to be able to edit the sailboat.py file and no need to refresh
# %load_ext autoreload 
# %autoreload 2

# %%
# optional stuff
# to not request the satelite tile every time
import cartopy.io.img_tiles as cimgt
request = cimgt.GoogleTiles(style='satellite')
#hide warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Test querrying the portal
# ## to get the url (and names for time varibales needed to parse dates):
# sb.gen_url(
#     telemetry='min',
#     BB3='min',
#     CI='min',
#     CT='min',
#     O2='min',
#     path=None,
#     date_interval=None,
#     limit=100,
# )
#
# options for groups of variables are a minimal set ('min'), all variables of the group ('all'), or none (None)
#
#
# ## to request the data from the portal
# sb.get_data(path, date_vars=['GPSTimeStamp'])

# %%
url, dates = sb.gen_url(limit=1000)
print(url)
df = sb.get_data(url, dates)
df.dtypes
# Out:
# Data variables are: ['GPSTimeStamp']
# http://portal.navocean.com/services/nav.php?req=data&id=VELA&columns=GPSTimeStamp%2CLon%2CLat%2CTrack%2CHeading%2CBb%28470%29+%5BNTU%5D%2CBb%28532%29+%5BNTU%5D%2CBb%28650%29+%5BNTU%5D%2CCDOM+%5BQSU%5D%2CChl.+a+%5Bppb%5D%2CPhycocyanin+%5Bppb%5D%2CConductivity+%5BmS+cm-1%5D%2CTemperature+%5Bdeg+C%5D%2CO2+Concentration+%5Bmicromolar%5D&format=csv&output=file&limit=1000&token=5e5c4d86-3fd9-11eb-904e-06ad0ec96835
# GPSTimeStamp                     datetime64[ns]
# Lon                                     float64
# Lat                                     float64
# Track                                   float64
# Heading                                 float64
# Conductivity [mS cm-1]                  float64
# Temperature [deg C]                     float64
# O2 Concentration [micromolar]           float64
# Bb(470) [NTU]                           float64
# Bb(532) [NTU]                           float64
# Bb(650) [NTU]                           float64
# CDOM [QSU]                              float64
# Chl. a [ppb]                            float64
# Phycocyanin [ppb]                       float64
# dtype: object

# %% [markdown]
# # "Easy" plots

# %% [markdown]
# ## Scatter plot

# %%
sb.scatter(df, 'chla', 'phyco')
# ax = sb.scatter(df, 'chla', 'phyco')
# ax.set_xlim(0,200)
# Out:
# <AxesSubplot:xlabel='Chl. a [ppb]', ylabel='Phycocyanin [ppb]'>

# %% [markdown]
# ## Path plot

# %%
sb.plot_path(df, 'cdom')

# %% [markdown]
# # Plotting with pandas

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1,2, figsize=(8,4), dpi=100, sharey=True)
#left
df['Chl. a [ppb]'].plot.hist(ax=axes[0])
axes[0].set_xlabel('Chl. a range')
#right
df['Phycocyanin [ppb]'].plot.hist(ax=axes[1])
axes[1].set_xlabel('Phyco range')
#fit
fig.tight_layout()

# %% [markdown]
# # Test loading local files

# %%
import glob

# %% [markdown]
# ## Files downloaded from portal

# %%
files = glob.glob('./Data/*.csv')
local = sb.get_data(files)
local['phyco/chla'] = local['Phycocyanin [ppb]']/local['Chl. a [ppb]']
local.dtypes
# Out:
# GPSTimeStamp                                 datetime64[ns]
# Lon                                                 float64
# Lat                                                 float64
# O2 Concentration [micromolar]                       float64
# O2 Saturation [%]                                   float64
# Bb(470) [NTU]                                       float64
# Bb(532) [NTU]                                       float64
# Bb(650) [NTU]                                       float64
# CDOM [QSU]                                          float64
# Chl. a [ppb]                                        float64
# Phycocyanin [ppb]                                   float64
# local time                       datetime64[ns, US/Eastern]
# phyco/chla                                          float64
# dtype: object

# %%
#subseting a month of data
subset = local[local['local time'].dt.month == 2]
#easy path plot
sb.plot_path(subset, 'cdom')

# %%
#stuff for animations
from celluloid import Camera
from IPython.display import HTML

#geographic projections
import cartopy.crs as ccrs

#time stuff
from datetime import datetime, timedelta
import calendar

import numpy as np

# %%
#subseting a month of data
month = 2
subset = local[(local['local time'].dt.year == 2021)&(local['local time'].dt.month == month)]

#plot color setings
back_color='black'
fore_color='white'
plt.rcParams["text.color"] = fore_color
plt.rcParams["axes.labelcolor"] = fore_color
plt.rcParams["xtick.color"] =  fore_color
plt.rcParams["ytick.color"] = fore_color

#Create figure
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=request.crs)
fig.patch.set_facecolor(back_color)

#colorbar ax
cax = fig.add_axes([.16, .83, .35, .04])

#for animation initialize camera
camera = Camera(fig)

#satelite image
sb.background(ax=ax, request=request)

# looping days
ndays = calendar.monthrange(2021, month)[1]
for d in range(ndays):
    day = subset[subset['local time'].dt.day == d+1]
    
    mpp = sb.plot_path(day, 'phyco/chla', vmin=0, vmax=1,
                       ax=ax, colorbar=False)

    #check if day has data
    if day.shape[0]>0:
        date = day['local time'].iloc[0] #extract date
    else:
        date += timedelta(days=1) #if no data for day, still get date

    #write date label
    ax.text(.15, .1, str(date)[:-15], fontsize=20, c='y', transform=ax.transAxes)
    
    #colorbar
    fig.colorbar(mpp, cax=cax,orientation='horizontal', label='Phycocyanin/Chl. a ratio')
    
    #snap camera for animation
    camera.snap()

# %%
anim = camera.animate(interval=1000)
# anim.save(calendar.month_abbr[month]+'_pcratio.mp4')
HTML(anim.to_html5_video())
# Out:
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## Event files

# %%
path = '/Users/hboi/OneDrive - Florida Atlantic University/HALO/navocean/Vela Sample Analysis Data and Results/'
mc = 'April Canal Point Microcystis/'
an = 'April Taylor Creek Anabaena/'

# %%
files = glob.glob(path+mc+'*.csv')
df_M = sb.get_data(files)
df_M.dtypes
# Out:
# GPSTimeStamp                                 datetime64[ns]
# Lon                                                 float64
# Lat                                                 float64
# Speed                                               float64
# Track                                               float64
# Heading                                             float64
# Pitch                                               float64
# Roll                                                float64
# WindTrueSpeed                                       float64
# WindTrueDir                                         float64
# PressureInches                                        int64
# AirTemp                                             float64
# BB3 [Time UTC]                                       object
# Bb(470) [counts]                                      int64
# Bb(532) [counts]                                      int64
# Bb(650) [counts]                                      int64
# CI [Time UTC]                                        object
# Chl. a [counts]                                     float64
# CDOM [counts]                                       float64
# Phycocyanin [counts]                                float64
# CT [Time UTC]                                        object
# Conductivity [mS cm-1]                              float64
# Temperature [deg C]                                 float64
# O2 [Time UTC]                                        object
# O2 Concentration [micromolar]                       float64
# O2 Saturation [%]                                   float64
# O2 Temperature [deg C]                              float64
# ADCP [Time UTC]                                      object
# X1 [m s-1]                                          float64
# Y1 [m s-1]                                          float64
# Z1 [m s-1]                                          float64
# X2 [m s-1]                                          float64
# Y2 [m s-1]                                          float64
# Z2 [m s-1]                                          float64
# X3 [m s-1]                                          float64
# Y3 [m s-1]                                          float64
# Z3 [m s-1]                                          float64
# Bb(470) [NTU]                                       float64
# Bb(532) [NTU]                                       float64
# Bb(650) [NTU]                                       float64
# CDOM [QSU]                                          float64
# Chl. a [ppb]                                        float64
# Phycocyanin [ppb]                                   float64
# local time                       datetime64[ns, US/Eastern]
# dtype: object

# %%
df_M['phyco/chla'] = df_M['Phycocyanin [counts]']/df_M['Chl. a [counts]']

# %%
sb.var_names(df_M)
# Out:
# {'time': 'GPSTimeStamp',
#  'lon': 'Lon',
#  'lat': 'Lat',
#  'speed': 'Speed',
#  'track': 'Track',
#  'heading': 'Heading',
#  'pitch': 'Pitch',
#  'wind speed': 'WindTrueSpeed',
#  'wind dir': 'WindTrueDir',
#  'pressure': 'PressureInches',
#  'air temp': 'AirTemp',
#  'bb3 time': 'BB3 [Time UTC]',
#  'bb470 counts': 'Bb(470) [counts]',
#  'bb532 counts': 'Bb(532) [counts]',
#  'bb650  counts': 'Bb(650) [counts]',
#  'bb470': 'Bb(470) [NTU]',
#  'bb532': 'Bb(532) [NTU]',
#  'bb650': 'Bb(650) [NTU]',
#  'ci time': 'CI [Time UTC]',
#  'chla counts': 'Chl. a [counts]',
#  'cdom counts': 'CDOM [counts]',
#  'phyco counts': 'Phycocyanin [counts]',
#  'chla': 'Chl. a [ppb]',
#  'cdom': 'CDOM [QSU]',
#  'phyco': 'Phycocyanin [ppb]',
#  'ct time': 'CT [Time UTC]',
#  'cond': 'Conductivity [mS cm-1]',
#  'temp': 'Temperature [deg C]',
#  'O2 time': 'O2 [Time UTC]',
#  'O2': 'O2 Concentration [micromolar]',
#  'O2 sat': 'O2 Saturation [%]',
#  'O2 temp': 'O2 Temperature [deg C]',
#  'local time': 'local time',
#  'X2 [m s-1]': 'X2 [m s-1]',
#  'ADCP [Time UTC]': 'ADCP [Time UTC]',
#  'Roll': 'Roll',
#  'Y1 [m s-1]': 'Y1 [m s-1]',
#  'Z1 [m s-1]': 'Z1 [m s-1]',
#  'X3 [m s-1]': 'X3 [m s-1]',
#  'Y2 [m s-1]': 'Y2 [m s-1]',
#  'Z2 [m s-1]': 'Z2 [m s-1]',
#  'Y3 [m s-1]': 'Y3 [m s-1]',
#  'X1 [m s-1]': 'X1 [m s-1]',
#  'phyco/chla': 'phyco/chla',
#  'Z3 [m s-1]': 'Z3 [m s-1]'}

# %%
#set figure
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection=request.crs)
fig.patch.set_facecolor(back_color)

#backgorund and path
sb.background(ax=ax,request = request)
mpp = sb.plot_path(df_M, 'phyco/chla', vmin=0, vmax=1,
                   ax=ax, colorbar=False)

#title
ax.set_title(str(df_M['local time'].iloc[-1]) + '   to   ' +str(df_M['local time'].iloc[0]), size= 20)

#colormap
cb = fig.colorbar(mpp, location='bottom', pad=.05)
cb.set_label('phyco/chla ratio')

# %%
fig = plt.figure(figsize=(5, 5))
fig.patch.set_facecolor(back_color)
ax = plt.axes(projection=request.crs)
#grid lines
gl = ax.gridlines(draw_labels=True, alpha=0.2,
                  ylocs=np.arange(26.86, 26.88, 0.001),
                 xlocs=np.arange(-80.65, -80.64, 0.001),
                 )
gl.xlabels_top = gl.ylabels_right = False
#path
mpp = sb.plot_path(df_M, 'phyco/chla', vmin=0, vmax=1,
                   ax=ax,)

# %%
fore_color='black'
# fore_color='white'
plt.rcParams["text.color"] = fore_color
plt.rcParams["axes.labelcolor"] = fore_color
plt.rcParams["xtick.color"] =  fore_color
plt.rcParams["ytick.color"] = fore_color

fig, axes = plt.subplots(4, 3, dpi=100, 
                         sharey='row', sharex='col',
                         figsize=(12,12))

y_vars = ['O2', 'cdom', 'phyco', 'temp']
c_vars = ['bb470', 'bb532', 'bb650']

for col, c_var in enumerate(c_vars):
    for row, y_var in enumerate(y_vars):
        sc = sb.scatter(df_M, 'chla', y_var, z_var=c_var, ax = axes[row,col], colorbar=False)
    fig.colorbar(sc.collections[0], ax=axes[0, col], location='top', label=c_var)
    axes[row, col].set_xlim(0,100)


fig.suptitle(str(df_M['local time'].iloc[-1])+' to '+ str(df_M['local time'].iloc[0]), fontsize=16)
# Out:
# Text(0.5, 0.98, '2021-04-26 10:39:59-04:00 to 2021-04-26 11:24:55-04:00')

# %%
file2 = glob.glob(path+an+'*.csv')
df2 = sb.get_data(file2)
df2['phyco/chla'] = df2['Phycocyanin [counts]']/df2['Chl. a [counts]']

# %%
fore_color='white'
plt.rcParams["text.color"] = fore_color
plt.rcParams["axes.labelcolor"] = fore_color
plt.rcParams["xtick.color"] =  fore_color
plt.rcParams["ytick.color"] = fore_color

fig = plt.figure(figsize=(10, 10))
fig.patch.set_facecolor(back_color)
ax = plt.axes(projection=request.crs)
sb.background(extent = [-81.15, -80.51,26.65, 27.24], ax=ax, 
           request = request)
ax.scatter(df2['Lon'], df2['Lat'],
               c=df2['phyco/chla'],
               vmin=0, vmax=1.,
               transform=ccrs.PlateCarree(),)
ax.set_title(str(df2['local time'].iloc[-1]) + '   to   ' +str(df2['local time'].iloc[0]), size= 20)
#colormap
cb = fig.colorbar(mpp, location='bottom', pad=.05)
cb.set_label('phyco/chla ratio')

# %%
fore_color='white'
plt.rcParams["text.color"] = fore_color
plt.rcParams["axes.labelcolor"] = fore_color
plt.rcParams["xtick.color"] =  fore_color
plt.rcParams["ytick.color"] = fore_color

fig = plt.figure(figsize=(5, 5))
fig.patch.set_facecolor(back_color)
ax = plt.axes(projection=request.crs)
#grid lines
gl = ax.gridlines(draw_labels=True, alpha=0.2,
#                   ylocs=np.arange(26.86, 26.88, 0.001),
                 xlocs=np.arange(-80.9, -80.79, 0.003),
                 )
gl.xlabels_top = gl.ylabels_right = False
#path
mpp = sb.plot_path(df2, 'phyco/chla', vmin=0, vmax=1,
                   ax=ax,)

# %%
fore_color='black'
plt.rcParams["text.color"] = fore_color
plt.rcParams["axes.labelcolor"] = fore_color
plt.rcParams["xtick.color"] =  fore_color
plt.rcParams["ytick.color"] = fore_color

fig, axes = plt.subplots(4, 3, dpi=100, 
                         sharey='row', sharex='col',
                         figsize=(12,12))

y_vars = ['O2', 'cdom', 'phyco', 'temp']
c_vars = ['bb470', 'bb532', 'bb650']

for col, c_var in enumerate(c_vars):
    for row, y_var in enumerate(y_vars):
        sc = sb.scatter(df2, 'chla', y_var, z_var=c_var, ax = axes[row,col], colorbar=False)
    fig.colorbar(sc.collections[0], ax=axes[0, col], location='top', label=c_var)
    axes[row, col].set_xlim(0,100)


fig.suptitle(str(df2['local time'].iloc[-1])+' to '+ str(df2['local time'].iloc[0]), fontsize=16)
# Out:
# Text(0.5, 0.98, '2021-04-21 12:00:01-04:00 to 2021-04-21 13:59:48-04:00')
